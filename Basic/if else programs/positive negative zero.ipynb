# %% [markdown]
# # check the no. is positive or negative

# %%
num = float(input("Enter a number"))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Zero
