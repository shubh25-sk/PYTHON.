# %% [markdown]
# #driving/voting

# %%
age = int(input("Enter your age: "))

if age >= 18:
    if age >= 21:
        print("You are eligible for voting and driving.")
    else:
        print("You are not eligible for voting but eligible for driving")
else:
    print("You are not eligible for driving.")
