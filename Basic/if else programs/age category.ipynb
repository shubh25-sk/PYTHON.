# %% [markdown]
# #age category

# %%
a=int(input("enter the age "))
if a>=60 :
   print("senior citizen") 
elif a>=18 :
   print("auldt")
elif a>=13 :
   print("teenager")
elif a>=0:
    print("child")
