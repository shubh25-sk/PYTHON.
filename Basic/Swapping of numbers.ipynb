# %%
#Swapping of two numbers

# %%
a=int(input("enter the first value "))
b=int(input("enter the second value"))

temp = a 
a=b
b=temp

print("after swaping")
print("a=",a)
print("b=",b)
# Out:
# after swaping
# a= 65
# b= 53
